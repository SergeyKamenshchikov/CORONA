# %% [markdown]
# Import libs:

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import matplotlib.pyplot as plt
from gluonts.model.deepar import DeepAREstimator
from gluonts.dataset.common import ListDataset
from gluonts.dataset.util import to_pandas
from gluonts.trainer import Trainer

# %% [markdown]
# Read data:

# %%
df = pd.read_csv('https://covid.ourworldindata.org/data/ecdc/total_cases.csv', header=0, index_col=0)
df_new = pd.DataFrame(df.sum(axis = 1, skipna = True), columns=['corona_cases']) 
df_new.head(3)
# Out:
#             corona_cases
# date
# 2019-12-31          54.0
# 2020-01-01          54.0
# 2020-01-02          54.0

# %% [markdown]
# Prepare train set:

# %%
training_data = ListDataset([{'start': df_new.index[0], 'target': df_new.corona_cases[:'25.03.2020']}], freq = 'D')

# %% [markdown]
# Train DeepAR:

# %%
estimator = DeepAREstimator(freq='D', prediction_length=30, trainer=Trainer(epochs=1000))
predictor = estimator.train(training_data=training_data)
# Out:
# INFO:root:Using CPU
# INFO:root:Start model training
# INFO:root:Epoch[0] Learning rate is 0.001
#   0%|                                                                                           | 0/50 [00:00<?, ?it/s]
# learning rate from ``lr_scheduler`` has been overwritten by ``learning_rate`` in optimizer.
# INFO:root:Number of parameters in DeepARTrainingNetwork: 25884
# 100%|█████████████████████████████████████████████████████████████| 50/50 [00:05<00:00,  9.16it/s, avg_epoch_loss=12.3]
# INFO:root:Epoch[0] Elapsed time 5.491 seconds
# INFO:root:Epoch[0] Evaluation metric 'epoch_loss'=12.317060
# INFO:root:Epoch[1] Learning rate is 0.001
# 100%|█████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.41it/s, avg_epoch_loss=10.5]
# INFO:root:Epoch[1] Elapsed time 4.389 seconds
# INFO:root:Epoch[1] Evaluation metric 'epoch_loss'=10.459243
# INFO:root:Epoch[2] Learning rate is 0.001
# ...

# %% [markdown]
# Fit-predict:

# %%
test_data = ListDataset([{'start': df_new.index[0], 'target': df_new.corona_cases[:'23.02.2020']}], freq = 'D')

for test_entry, forecast in zip(test_data, predictor.predict(test_data)):
    to_pandas(test_entry).plot(linewidth=2, figsize=(10,6), label="historical values")
    forecast.plot(color='g', prediction_intervals=[50.0, 90.0], label="forecast", show_mean=True)

plt.axvline(x= df_new.index[-1], color='gray', linestyle='--', linewidth=6)    
plt.title('Corona cases - GluonTS forecast')
plt.legend(loc='upper left')
plt.grid(axis='x')
